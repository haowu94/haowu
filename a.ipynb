# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Hao Wu__<br>
# Financial Analyst

# %% [markdown]
# ***I am interested in data science because I want to solve problems scientifically.

# %% [markdown]
# ### caculate 2+2

# %%
a = 2+2
print(a)
# Out:
# 4

# %% [markdown]
# '$***https://github.com/$'
